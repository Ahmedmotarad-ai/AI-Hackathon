# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %%
# Load the raw transaction records into a DataFrame
df = pd.read_csv("Smart Healthcare - Daily Lifestyle Dataset (Wearable device).csv")

# Report the dataset size 
print(f"Rows: {df.shape[0]:,}")
print(f"Columns: {df.shape[1]}")
# Out:
# Rows: 700
# Columns: 15

# %%
# Load the raw transaction records into a DataFrame
df = pd.read_csv("wearables_health_6mo_daily.csv")

# Report the dataset size 
print(f"Rows: {df.shape[0]:,}")
print(f"Columns: {df.shape[1]}")
# Out:
# Rows: 55,200
# Columns: 33

# %%
# Load the raw transaction records into a DataFrame
df = pd.read_csv("mturkfitbit_export_3.12.16-4.11.16/Fitabase Data 3.12.16-4.11.16/heartrate_seconds_merged.csv")

# Report the dataset size 
print(f"Rows: {df.shape[0]:,}")
print(f"Columns: {df.shape[1]}")
# Out:
# Rows: 1,154,681
# Columns: 3

# %%
df["user_id"].nunique()
# Out:
# 300
